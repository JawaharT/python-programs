# %%
import pandas as pd
stats = pd.read_csv('/Users/Jawahar/Desktop/Programming/Python Data Science/P4-Demographic-Data.csv')
#print(len(stats)) #195 rows
#print(stats.columns) #5 columns
#print(stats.head(6))
#print(stats.tail(6))
#print(stats.info())
#print(stats.describe())
#pd.set_option('expand_frame_repr', False)
#pd.set_option('display.max_columns', 999)
#print(stats.describe().transpose())
stats.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers', 'IncomeGroup']
#print(stats.head())
#stats[::-1] #working with rows just like matrices and lists
#stats['CountryName'].head()
#stats[['CountryName', 'CountryCode']].head() #Need list of column titles to output the columns you want in any order
#stats.InternetUsers.head() #Quick access to a single column
#stats[4:8][['CountryName', 'CountryCode']] #Can subset rows and columns one go
#stats[['CountryName', 'CountryCode']][4:8] #Can subset columns and rows, same result as the one above
#print(stats[stats.IncomeGroup == 'High income']) #subset of high income countries
#print(stats[(stats['IncomeGroup']=='Low income') & (stats['InternetUsers']<90)]) #subset when comparing multiple columns & operator used to indicate bitwise iterations
#print(stats[stats['CountryName'] == 'Malta'])
#print(stats.iat[3,4]) #Counts to the element in position given in square brackets (Need to physically count)
#print(stats.at[1,'CountryName']) #Uses labels on the label to access an element on table (Looks for element with those labels specified)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = 9,4

# %%
#plt.grid(color='grey', linestyle='-', linewidth=2)
print(sns.distplot(stats['BirthRate'], bins=30))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(sns.boxplot(data=stats, x='IncomeGroup', y='BirthRate'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(sns.lineplot(x="InternetUsers", y="BirthRate",hue="IncomeGroup",data=stats))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(sns.lmplot(data=stats, x='InternetUsers', y='BirthRate', fit_reg=False, hue='IncomeGroup', height=6, scatter_kws={'s':100}))
